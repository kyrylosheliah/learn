# %%
from geneticalgorithm import geneticalgorithm as ga

def target_function(X):
    return X[0]**2 - 2*X[0]*X[1] + 6*X[0] + X[1]**2 - 6*X[1]

domains=np.array([[-10,10]]*2)

model=ga(function=objectiveFunction,dimension=2,variable_type='real',variable_boundaries=domains)

model.run()
# Out:
#  The best solution found:
#  [9.54916491 9.54910312]
#
#  Objective function:
#  -221.4263972268147

# %%
import numpy as np
from mpl_toolkits.mplot3d import Axes3D  
# Axes3D import has side effects, it enables using projection='3d' in add_subplot
import matplotlib.pyplot as plt

def fun(x, y):
    return target_function([x, y])

fig = plt.figure(dpi=200)
ax = fig.add_subplot(111, projection='3d')
x = np.arange(domains[0][0], domains[0][1], 0.1)
y = np.arange(domains[1][0], domains[1][1], 0.1)
X, Y = np.meshgrid(x, y)
zs = np.array(fun(np.ravel(X), np.ravel(Y)))
Z = zs.reshape(X.shape)

ax.plot_surface(X, Y, Z)

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

ax.view_init(azim=45, elev=20)

plt.show()
